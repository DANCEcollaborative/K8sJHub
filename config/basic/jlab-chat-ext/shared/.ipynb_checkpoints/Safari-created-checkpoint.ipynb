# %%
print("safari-created cell in safari-created notebook")
# Out:
# safari-created cell in safari-created notebook

# %%
print("chrome-created cell in chrome-created notebook")
# Out:
# chrome-created cell in chrome-created notebook

# %%
print("chrome-created cell in chrome-created notebook, 2025-08-01 17:18")

# %%
print("Safari-created cell in chrome-created notebook, 2025-08-01, 17:19")
# Out:
# Safari-created cell in chrome-created notebook, 2025-08-01, 17:19

# %%
print("hello from chrome!")
# Out:
# hello from chrome!
