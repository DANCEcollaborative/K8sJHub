# %%
print("Chrome chat in Safari-created notebook & cell")
# Out:
# Chrome chat in Safari-created notebook & cell

# %%
print("Safari chat in Safari-create notebook & cell")
# Out:
# Safari chat in Safari-create notebook & cell

# %%
print("Chrome cell in Safari nb")
# Out:
# Chrome cell in Safari nb
